# %%
from getReplicaRMSD import getReplicaRMSD
from getReplicaCCC import getReplicaCCC
from plotReplicaRMSD import plotReplicaRMSD
from plotReplicaCCC import plotReplicaCCC
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(3,1)
fig.set_figwidth(12)
fig.set_figheight(10)
plotReplicaRMSD(0, color='k', ax=ax[0])
plotReplicaCCC(0, color='k', ax=ax[1])
#plotEMRing(color='k', ax=ax[2])
ax[0].set_xticks([])
ax[0].set_xlabel('')
ax[0].yaxis.set_tick_params(labelsize=18)
ax[1].set_xticks([])
ax[1].set_xlabel('')

ax[2].set_xticks([0,200,400,600,800])
ax[2].set_xlabel('Frame #', fontsize=24)
ax[2].xaxis.set_tick_params(labelsize=24)
ax[2].yaxis.set_tick_params(labelsize=18)
ax[2].set_yticks([])
plt.savefig("Figure3_leftPanel.pdf")
plt.show()
